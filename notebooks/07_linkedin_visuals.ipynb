# %% [markdown]
# # Stage 8 - LinkedIn-Ready Visualisations
#
# Generate polished, dark-red "World Cup" themed infographics at 300 DPI from the
# project's **real outputs only** - inspired by, but not copied from, the Kaggle
# reference images.
#
# Sources: `outputs/fixtures_2026_predictions.csv` (authoritative fixtures),
# `outputs/champion_probabilities.csv`, `outputs/advancement_probabilities.csv`,
# `outputs/model_results.csv`.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from IPython.display import Image
from src import config, linkedin_visuals as lv
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Generate all visuals

# %%
paths = lv.generate_all()
# Out:
# Generated LinkedIn visuals:
#   - /Users/nguyenthingochong/Projects/worldcup-2026-prediction/outputs/linkedin_visuals/champion_probabilities_top15.png
#   - /Users/nguyenthingochong/Projects/worldcup-2026-prediction/outputs/linkedin_visuals/group_stage_match_cards_A_F.png
#   - /Users/nguyenthingochong/Projects/worldcup-2026-prediction/outputs/linkedin_visuals/group_stage_match_cards_G_L.png
#   - /Users/nguyenthingochong/Projects/worldcup-2026-prediction/outputs/linkedin_visuals/most_likely_tournament_path.png
#   - /Users/nguyenthingochong/Projects/worldcup-2026-prediction/outputs/linkedin_visuals/full_decision_tree_bracket.png
#   - /Users/nguyenthingochong/Projects/worldcup-2026-prediction/outputs/linkedin_visuals/pipeline_summary.png
#   - /Users/nguyenthingochong/Projects/worldcup-2026-prediction/outputs/linkedin_visuals/validation_bug_fix.png

# %% [markdown]
# ## 1 - Hero: champion probabilities (carousel cover)

# %%
Image(filename=str(config.LINKEDIN_DIR / "champion_probabilities_top15.png"), width=620)

# %% [markdown]
# ## 2 - Match prediction cards (Groups A-F, G-L)

# %%
Image(filename=str(config.LINKEDIN_DIR / "group_stage_match_cards_A_F.png"), width=820)

# %%
Image(filename=str(config.LINKEDIN_DIR / "group_stage_match_cards_G_L.png"), width=820)

# %% [markdown]
# ## 3 - Full decision-tree bracket (all 32 teams)

# %%
Image(filename=str(config.LINKEDIN_DIR / "full_decision_tree_bracket.png"), width=920)

# %% [markdown]
# ## 3b - Most likely tournament path (champion's road)

# %%
Image(filename=str(config.LINKEDIN_DIR / "most_likely_tournament_path.png"), width=860)

# %% [markdown]
# ## 4 - Project pipeline

# %%
Image(filename=str(config.LINKEDIN_DIR / "pipeline_summary.png"), width=620)

# %% [markdown]
# ## 5 - Validation / bug-fix story

# %%
Image(filename=str(config.LINKEDIN_DIR / "validation_bug_fix.png"), width=620)

# %% [markdown]
# ## Recommended LinkedIn carousel order
#
# 1. **Champion probabilities** (cover - strongest hook)
# 2. **Full decision-tree bracket** (the marquee visual)
# 3. **Match prediction cards A-F**
# 4. **Match prediction cards G-L**
# 5. **Most likely tournament path** (champion's road - optional close-up)
# 6. **Pipeline summary**
# 7. **Validation / bug-fix story** (credibility closer)
#
# All images are dark-themed, 300 DPI, and built only from real project outputs.
